# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
import time
import re

# %%
text_file_dir = "../data/wikispeedia_articles_plaintext/plaintext_articles/"
file_data = []

for filename in os.listdir(text_file_dir):
    if filename.endswith(".txt"):  # Ensure you're only reading .txt files
        with open(os.path.join(text_file_dir, filename), 'r', encoding='utf-8') as file:
            content = file.read()
        
            # Split the content into lines to remove the header
            lines = content.split('\n')

            # Removing the header (line 0) and join back the content
            if lines:
                title = lines.pop(2)  # Assuming the first line is the title
            
            content = ' '.join(lines).replace("\n", " ")
            
            # Create a dictionary with title and content
            file_data.append({"title": title, "text_content": content})

# Create a DataFrame
project_data = pd.DataFrame(file_data)

# Display the DataFrame structure
print(project_data.head())

article_titles = project_data['title'].tolist()
article_titles
# Out:
#                          title  \
# 0               Second Crusade
# 1               Navassa Island
# 2             Evan Rachel Wood
# 3  Tropical Storm Henri (2003)
# 4      Final Fantasy Adventure
#
#                                         text_content
# 0     #copyright   2007 Schools Wikipedia Selecti...
# 1     #copyright   2007 Schools Wikipedia Selecti...
# 2     #copyright   2007 Schools Wikipedia Selecti...
# 3     #copyright   2007 Schools Wikipedia Selecti...
# 4     #copyright   2007 Schools Wikipedia Selecti...
# ['Second Crusade',
#  'Navassa Island',
#  'Evan Rachel Wood',
#  'Tropical Storm Henri (2003)',
#  'Final Fantasy Adventure',
#  'Tornado',
#  'John W. Campbell',
#  'Whooping Crane',
#  'Shigin',
#  'Hafnium',
#  'Hawaiian Goose',
#  'Ankylosaurus',
#  'Andriyivskyy Descent',
#  'Supermarine Spitfire',
#  'Carl Jung',
#  'Fine art',
#  'Arithmetic',
#  'Taj Mahal',
#  'Social capital',
#  'Nepal',
#  'Book of Common Prayer',
#  'African Buffalo',
#  'Luminiferous aether',
#  'Chicago',
#  'Giza pyramid complex',
#  'Lyme disease',
#  'Humour',
#  'Imperative programming',
#  'Brain',
#  'Coconut',
#  'Tern',
#  'Wars of the Roses',
#  'Davis Cup',
#  'Great Tit',
#  'Wave–particle duality',
#  'Jean Charles de Menezes',
#  'Local community',
#  'Music of Spain',
#  'Terik',
#  'Bernard Hinault',
#  "Hickman's potentilla",
#  'Eris (dwarf planet)',
#  'Intelligence',
#  'Margaret Sanger',
#  'Bretton Woods system',
#  'Glastonbury Festival',
#  'Oxygen',
#  'Gerald Ford',
#  'Antarctic Treaty System',
#  'John Locke',
#  'Martin Luther King, Jr.',
#  'Six-party talks',
#  'Coot',
#  'Nintendo Entertainment System',
#  'Beet',
#  'New York City',
#  'Space Shuttle Endeavour',
#  'John Dee',
#  'Eifel Aqueduct',
#  'Three Gorges Dam',
#  'Akkadian Empire',
#  'Bette Davis',
#  'Indian Ocean',
#  'Tel Aviv',
#  'England',
#  'Philip II of Spain',
#  'Carrot',
#  'Australian Ringneck',
#  'Special relativity',
#  'Michael Woodruff',
#  'Cubism',
#  'Biosphere',
#  'Diamond cut',
#  'Coconut crab',
#  'Gibraltar',
#  'Hurricane John (1994)',
#  'American Civil War',
#  'Hubble Space Telescope',
#  'Introduction to special relativity',
#  'Carbon dioxide',
#  'Marco Polo',
#  'ATLAS experiment',
#  'Cape Canaveral',
#  'California Southern Railroad',
#  'Barium',
#  'Sauroposeidon',
#  'Brighton',
#  'Douglas Adams',
#  'Northern Pacific Railway',
#  'Mind',
#  'The Anarchy',
#  'Baltimore, Maryland',
#  'Sanskrit',
#  'Blue Whale',
#  'Santa Claus',
#  'OpenOffice.org',
#  'Krazy Kat',
#  'Irrigation',
#  'Material properties of diamond',
#  'Wildebeest',
#  'Parsley',
#  'Holy Roman Empire',
#  'John A.T. Robinson',
#  'Famine',
#  'Gowanus Canal',
#  'Zebra',
#  'Defense of Sihang Warehouse',
#  'Stock',
#  'Christian monasticism',
#  'Mathematics',
#  'Tree Sparrow',
#  'Community',
#  'University of Chicago',
#  'Prague',
#  'Corundum',
#  'Toy',
#  'Tasmanian Devil',
#  'Medal of Honour',
#  'Roan Antelope',
#  'Allah',
#  'Roche limit',
#  'Indira Gandhi',
#  'Ska',
#  'Battle of the Santa Cruz Islands',
#  'Aluminium',
#  'British House of Commons',
#  'The Lord of the Rings film trilogy',
#  'Blackpool',
#  'Bridge',
#  'AC/DC',
#  'Radon',
#  'William N. Page',
#  'Hasekura Tsunenaga',
#  'Grover Cleveland',
#  'Troop sleeper',
#  'Absolute zero',
#  'Pony',
#  'Apatosaurus',
#  'Edward Teller',
#  'City',
#  'Gliding',
#  'Renaissance',
#  'Gold standard',
#  'Radar',
#  'Asia',
#  'William Thomson, 1st Baron Kelvin',
#  'Copper(I) chloride',
#  '15th Marine Expeditionary Unit',
#  'Joseph Haydn',
#  "One Flew Over the Cuckoo's Nest (novel)",
#  'Poetry of the United States',
#  'Corporate finance',
#  'Camel',
#  'Seinfeld',
#  'Pollinator',
#  'Saint-Pierre and Miquelon',
#  'Formula One',
#  'James Cook',
#  '7th century',
#  'Internet Explorer',
#  'Feldspar',
#  'Lake Superior',
#  'Palace of Westminster',
#  'Full moon',
#  'Sichuan Pepper',
#  'Myocardial infarction',
#  'Star Wars Episode IV: A New Hope',
#  'World Health Organization',
#  'Beeching Axe',
#  'Guam',
#  'Julius Caesar',
#  'Abacá',
#  'Snow Goose',
#  'Isaac Asimov',
#  'Egyptian pyramids',
#  'Silurian',
#  'Eurasian Collared Dove',
#  'Goleta, California',
#  'Mongol Empire',
#  'Hurricane Marty (2003)',
#  'Newshounds',
#  'Screw',
#  'Rook (bird)',
#  'Eyelid',
#  'Mammal',
#  'Albatross',
#  'Eruption column',
#  'Energy',
#  'Isan',
#  'Beep (SWBLW)',
#  'Isles of Scilly',
#  'Swan',
#  'Cerebellum',
#  'La Paz',
#  'Literacy',
#  'Bantu',
#  'Eagle',
#  'Black-backed Jackal',
#  'Explorer I',
#  'The Hobbit',
#  'Du Fu',
#  'Turkey',
#  'Canadian Pacific Railway',
#  'Space exploration',
#  'Saint Joan (play)',
#  'Toy Story',
#  'Juan Sebastián Elcano',
#  'Prion',
#  'Wikipedia',
#  'Lego',
#  'GNU',
#  'Waheguru',
#  'Imagism',
#  'Archaeopteryx',
#  'Catholic social teaching',
#  'Gordon Brown',
#  'Lisbon',
#  'Lerwick',
#  'Monaco',
#  'Richard Stallman',
#  'Thermodynamics',
#  'The Marriage of Figaro',
#  'Chess',
#  'Bismuth',
#  'Backgammon',
#  'Thomas Becket',
#  'Battle of France',
#  'Otto von Bismarck',
#  'Stained glass',
#  'Dallas, Texas',
#  'Montreal Metro',
#  'Berlin',
#  'Japanese war crimes',
#  'John Maynard Keynes',
#  'Nuclear weapon',
#  'Roald Amundsen',
#  'John Calvin',
#  'Country',
#  'Eurasian Jay',
#  'Refrigerator car',
#  "The Pilgrim's Progress",
#  'Cotton',
#  'Cricket',
#  'Nephron',
#  'Australia',
#  'Cereal',
#  'Frederick II of Prussia',
#  'Sumo',
#  'Rabat',
#  'Flamingo',
#  'Fermi paradox',
#  'Henry V of England',
#  'Maiasaura',
#  'Cameroon',
#  'Sunset Boulevard (1950 film)',
#  'Carl Friedrich Gauss',
#  'Europium',
#  'Akrotiri and Dhekelia',
#  'Roman villa',
#  'FairTax',
#  'Marshall Plan',
#  'Robert Oppenheimer',
#  'Helen Gandy',
#  'Blood type',
#  'History of the Australian Capital Territory',
#  '3rd century',
#  'Humus',
#  'Macau',
#  'Archbishop of Canterbury',
#  'Automated teller machine',
#  'Kiev',
#  'Conakry',
#  "Bahá'í Faith",
#  'Pythagoras',
#  'Natural selection',
#  'Royal Geographical Society',
#  'J. K. Rowling',
#  'Black hole',
#  'Soddo language',
#  'Boeing 747',
#  'Channel Islands',
#  'Ammonia',
#  'Astrology',
#  'Radio telescope',
#  'Eric Clapton',
#  'England expects that every man will do his duty',
#  'English monarchs family tree',
#  'Alcohol',
#  'Jackanory',
#  'Rome',
#  'Bushbuck',
#  'Drawing',
#  'L. S. Lowry',
#  'Manchester United F.C.',
#  'Negros Oriental',
#  'Newsround',
#  'Nintendo',
#  'Royal Dutch Shell',
#  'Functional programming',
#  'Edmonton',
#  'Jerry Fodor',
#  'Oenothera',
#  'Andrew Dickson White',
#  'First Macedonian War',
#  'Driving on the left or right',
#  'List of essential oils',
#  'Sand shark',
#  'South Georgia and the South Sandwich Islands',
#  'Ancient history',
#  'Battle of Cannae',
#  'Turkish Republic of Northern Cyprus',
#  'Lyndon B. Johnson',
#  'Amtrak',
#  'African Grey Parrot',
#  'Volcanic pipe',
#  'Financial statements',
#  'Cornell University',
#  'Cymbopogon',
#  'Mammoth',
#  'Badminton',
#  'Extraterrestrial life',
#  'Bob Marley',
#  'Crimean War',
#  'Mozambique',
#  'Assyria',
#  'Sandy Koufax',
#  'Brazil',
#  'Max Planck',
#  'Stanley, Falkland Islands',
#  'Citizen Kane',
#  'Denver, Colorado',
#  'Chemistry',
#  '15th century',
#  'Modern history',
#  'Buckminster Fuller',
#  'Wood Pigeon',
#  'Andrew Gonzalez',
#  'God',
#  'Bird',
#  'Kākāriki',
#  'Metamorphic rock',
#  'Benin',
#  'Black Sea',
#  'Cat Stevens',
#  'American English',
#  'George Washington',
#  'Honey bee',
#  'Marcel Proust',
#  'Archaeoastronomy',
#  'Land (economics)',
#  'Wallaby',
#  'Einsteinium',
#  'Greece',
#  'Television',
#  'Vincent van Gogh',
#  'Constructivism (art)',
#  'Mississippi River',
#  'Eliminative materialism',
#  'Guangzhou',
#  'The Quatermass Experiment',
#  'Fascism',
#  'Columba',
#  'Andorra',
#  'Pochard',
#  'Jórvík',
#  'Automobile',
#  'Bucharest',
#  'Nickel',
#  'Calcite',
#  'London Zoo',
#  'Desert locust',
#  'Edward II of England',
#  'Music',
#  'Mirabilis (plant)',
#  'Football (soccer)',
#  'Falkirk Wheel',
#  'Mango',
#  'Armand Jean du Plessis, Cardinal Richelieu',
#  'Old Nubian language',
#  'United States Constitution',
#  'Milky Way',
#  'Blackcap',
#  'J. R. R. Tolkien',
#  'Adolf Hitler',
#  'Shark',
#  'Trafalgar Square',
#  'Kashmir region',
#  'Josephus',
#  'Mbabane',
#  'Library',
#  'Stephen Trigg',
#  'Christianity',
#  'Albert Einstein',
#  'Barbara McClintock',
#  'Cædmon',
#  'Philosophy of mind',
#  'Empiricism',
#  'Kipchaks in Georgia',
#  'Able Archer 83',
#  'Steve Davis',
#  'One Foot in the Grave',
#  'Plutonium',
#  'Family',
#  'Rosemary',
#  'William McKinley',
#  'Lighthouse of Alexandria',
#  'Fedora Core',
#  'Chew Stoke',
#  'Barcelona',
#  'Gossypium',
#  'Tim Henman',
#  'Jarvis Island',
#  'Geology of the Grand Canyon area',
#  'Pelycosaur',
#  'Bonobo',
#  'Jyllands-Posten Muhammad cartoons controversy',
#  'Badugi',
#  'A Tale of a Tub',
#  'Calculus',
#  'Roman road',
#  'Margate',
#  'Juvenile delinquency',
#  'Ostrich',
#  'John Constable',
#  '11th century',
#  'Louis Freeh',
#  'Bicycle Thieves',
#  'Stockholm',
#  'Santamaría (volcano)',
#  'The Old Man and the Sea',
#  'Poultry',
#  'General Pershing Zephyr',
#  'Tiger',
#  'Aymer de Valence, 2nd Earl of Pembroke',
#  'Animation',
#  'Dante Alighieri',
#  'William Mahone',
#  'Black Wildebeest',
#  '',
#  'Work (thermodynamics)',
#  '1755 Lisbon earthquake',
#  'GNU/Linux naming controversy',
#  'Mars Exploration Rover',
#  'Skiing',
#  'Meteor shower',
#  'Keira Knightley',
#  'North Korea',
#  'Educational psychology',
#  'White-tailed Eagle',
#  'Europe',
#  'Muscat, Oman',
#  'Battle of Vaslui',
#  'Kangaroo',
#  'Magdalena Abakanowicz',
#  'Lake Edward',
#  'Oasis (band)',
#  'Bongo (antelope)',
#  'World Bank Group',
#  'Democracy',
#  'Ammonite',
#  'Oxford',
#  'Algoma Central Railway',
#  'Armadillo',
#  '2003 Atlantic hurricane season',
#  'Sweden',
#  'History of Alaska',
#  'Moscow',
#  'Richard Feynman',
#  'Long pepper',
#  'Roman law',
#  'Edward Jenner',
#  'African Jacana',
#  'Helicobacter pylori',
#  'Jacob Riis',
#  'Richard Nixon',
#  'Seychelles',
#  'Roman Catholic Church',
#  'Burundi',
#  'Blacktip reef shark',
#  'Celery',
#  'Mummy',
#  'Tofu',
#  'Ultimatum game',
#  'Metric expansion of space',
#  'Hurricane Andrew',
#  'Swastika',
#  'Chicken',
#  'Island Fox',
#  'Publishing',
#  'Royal Grammar School Worcester',
#  "Côte d'Ivoire",
#  'PSR B1620-26c',
#  'Moldova',
#  'Anton Alexander von Werner',
#  'Esperanto',
#  'HD 28185',
#  'Monarchies in the European Union',
#  'Scientific classification',
#  'Gone with the Wind (film)',
#  'Woodruff',
#  'Honey',
#  'Tripoli',
#  '1896 Summer Olympics',
#  'Sucre',
#  'Spinosaurus',
#  'Political philosophy',
#  'Ann Arbor, Michigan',
#  "People's Republic of China",
#  'Rudolf Vrba',
#  'Nitrogen cycle',
#  'Shinto',
#  'Burr-Hamilton duel',
#  'Pac-Man',
#  'Bede',
#  'Auckland',
#  'Surtsey',
#  'New York City Subway nomenclature',
#  'European Goldfinch',
#  'Stuttering',
#  'Great Yarmouth',
#  'Sputnik program',
#  'Supply and demand',
#  'Ubuntu (Linux distribution)',
#  'Anglican Communion',
#  'Inductance',
#  'Amber',
#  'Endoscopic foreign body retrieval',
#  'Annibale Bugnini',
#  'List of North American countries',
#  'Biotechnology',
#  'Forest',
#  'Katana',
#  'Beekeeping',
#  'Cactus',
#  'Palazzo Pitti',
#  'International English',
#  'Portuguese language',
#  'Joseph Stalin',
#  'Sirius',
#  'Tower of London',
#  'Mary Somerville',
#  'The Fairy-Queen',
#  'Eastern Orthodox Church',
#  'Hernán Cortés',
#  'Globular cluster',
#  'Oceania',
#  'Elfin-woods Warbler',
#  'List of U.S. states by date of statehood',
#  'William and Mary',
#  'Antananarivo',
#  'Chemical element',
#  'White cliffs of Dover',
#  'Vitus Bering',
#  'King Arthur',
#  'Homestar Runner',
#  'Arsenic',
#  'Lake Mead',
#  'Triggerplant',
#  'Roman mythology',
#  'Trade and usage of saffron',
#  'Temple of Artemis',
#  'Belgium',
#  'Opus Dei',
#  'Life',
#  'Speech synthesis',
#  'Melbourne',
#  'X Window core protocol',
#  'List of areas in the National Park System of the United States',
#  '16th century',
#  'History of education',
#  'Boy Scout',
#  'Hypsilophodon',
#  'Gregorian chant',
#  'Charles Babbage',
#  'Algebra',
#  'Extinction',
#  'Bluegrass music',
#  'Martello tower',
#  'Niger River',
#  'Black Seminoles',
#  'Fugu',
#  'Banjul',
#  'Terrorism',
#  'Hawking radiation',
#  'Behavioural finance',
#  'Nine Million Bicycles',
#  'Mesopotamia',
#  'Deluge (mythology)',
#  'Drought',
#  'Universe',
#  'Water purification',
#  'Pre-Raphaelite Brotherhood',
#  'David Heymann',
#  'Volcano',
#  'United for Peace and Justice',
#  'History of Russia',
#  'Winfield Scott (ship)',
#  'Longship',
#  'Billie Holiday',
#  'Yorkshire Dales',
#  'Sydney Newman',
#  'Long-billed Vulture',
#  'Fossil',
#  'Ceres (dwarf planet)',
#  'Sodium hydroxide',
#  '21st century',
#  'Thomas Samuel Kuhn',
#  'Ernest Hemingway',
#  'List of rivers by length',
#  'Tonga',
#  'Aarhus',
#  'Working poor',
#  'Aphid',
#  'Goa',
#  'San Francisco de Quito',
#  'Firearm',
#  'Montserrat',
#  'Al Jazeera',
#  'Peter Paul Rubens',
#  'Denis Law',
#  'Beer',
#  'Snow',
#  'Lipid',
#  'Australian rules football',
#  'Macbeth of Scotland',
#  'Diabetes mellitus',
#  'Henry Fonda',
#  'Funchal',
#  'Water Buffalo',
#  'Star Trek',
#  'H.D.',
#  'Trans-Siberian Railway',
#  'Argon',
#  'Tropical Storm Chris (2006)',
#  'Rondane National Park',
#  'Pied Avocet',
#  'Battle of the Bulge',
#  'Convention on the Rights of the Child',
#  'Africa',
#  'Russian constitutional crisis of 1993',
#  'Cyanocobalamin',
#  'Antlion',
#  'Alcibiades',
#  'Open source',
#  'Augusta, Lady Gregory',
#  'Pennsylvania Railroad',
#  'Erwin Rommel',
#  'Crimson-collared Tanager',
#  'Friedrich Nietzsche',
#  'Employment',
#  'Osmium',
#  'Spirit of the American Doughboy',
#  'Castra',
#  'Hurricane Felix (1995)',
#  'History of Anglo-Saxon England',
#  'Jet Set Willy',
#  'Star Fox: Assault',
#  'Tobacco',
#  'Boston and Lowell Railroad',
#  'Darling River',
#  'Thiamine',
#  'Ivan IV of Russia',
#  'San Diego Electric Railway',
#  'Oat',
#  'Cocos (Keeling) Islands',
#  'Electric charge',
#  'Hubbard Glacier',
#  'Qin Dynasty',
#  'Harry S. Truman',
#  '1973 oil crisis',
#  'Richard Wagner',
#  'Order of the Thistle',
#  'Investment banking',
#  'Zoroaster',
#  'Berkelium',
#  'Post-glacial rebound',
#  'Ant',
#  'Battle of the Little Bighorn',
#  'Montenegro',
#  'Earwax',
#  "Children's Machine",
#  'Tobacco smoking',
#  'History of Miami, Florida',
#  'Santorini',
#  'Mahjong',
#  'Mahabharata',
#  'Indian cricket team',
#  "Hundred Years' War",
#  'Arnold Schwarzenegger',
#  'Odin',
#  'List of minerals',
#  'Medicine',
#  'Charlie Chaplin',
#  'Fishing',
#  'Budapest',
#  'Bermuda',
#  'Socialism',
#  'Augustan literature',
#  'Van Halen',
#  'Philately',
#  'Genetic code',
#  'Hannibal Barca',
#  'Chimpanzee',
#  'Wood',
#  'Gottfried Leibniz',
#  'Mark Webber',
#  'Spanish Inquisition',
#  'Franklin Pierce',
#  'Madagascar',
#  'Elizabethan Poor Law (1601)',
#  'Grenada',
#  'Anthony van Dyck',
#  'Tooth development',
#  'Microsoft',
#  '1980 eruption of Mount St. Helens',
#  'Optical telescope',
#  'Ancient Rome',
#  'Hurricane David',
#  'Mandan',
#  'List of members of the Commonwealth of Nations by date joined',
#  'William I of England',
#  'Papal conclave',
#  'United Kingdom',
#  'Battle of Tours',
#  'Cayman Islands',
#  'Cod',
#  'Lusaka',
#  'Polymerase chain reaction',
#  '',
#  'Ecuador',
#  'Planetary habitability',
#  'Peter Grimes',
#  'Jonathan Wild',
#  'Protein',
#  'Auguste Rodin',
#  'USS Wisconsin (BB-64)',
#  'Mongol invasion of Central Asia',
#  'Social contract (Malaysia)',
#  'Niagara Falls',
#  'History of South Carolina',
#  'Seoul',
#  'Rosetta Stone',
#  'Maseru',
#  'United States Numbered Highways',
#  'Gmail',
#  'Shrine of Remembrance',
#  '2-8-0',
#  'Miocene',
#  'Typewriter',
#  'Titanosaur',
#  'Rupee',
#  'United States House of Representatives',
#  'Steam engine',
#  'Nairobi',
#  'Alliterative verse',
#  'Boundary Waters Canoe Area Wilderness',
#  'Milk',
#  'Halloween',
#  'Holmium',
#  'Cookiecutter shark',
#  'Lens (anatomy)',
#  'Trabancos River',
#  'North Africa',
#  'Andrew Johnson',
#  'Aristarchus (crater)',
#  'Bob Dylan',
#  'Cheetah',
#  'Magma',
#  'United Kingdom national football team',
#  'Windows 2000',
#  'Nuthatch',
#  'Minstrel show',
#  'Renormalization',
#  'Maya mythology',
#  'Onion',
#  'Cyprus',
#  'Gull',
#  'ABO blood group system',
#  'Sino-Roman relations',
#  'Winter',
#  'Gorilla',
#  'Gabon',
#  'Tiger Woods',
#  'Victoria, Seychelles',
#  'Boston RFC',
#  'East Timor',
#  '12th century',
#  'Music of Hawaii',
#  'Phineas Gage',
#  'Plateosaurus',
#  'Charles Sumner',
#  'Elephant bird',
#  'Uranium',
#  'Doom',
#  'William Gladstone',
#  'Bionicle: Mask of Light',
#  'Transit of Venus',
#  'Agriculture',
#  'Ammolite',
#  'Song Thrush',
#  'Troodon',
#  'Christmas Island',
#  'Capitoline Triad',
#  'Watling Street',
#  'Green Woodpecker',
#  'Garage (dance music)',
#  'The Country Wife',
#  'Alan Turing',
#  'Sino-German cooperation (1911-1941)',
#  'Ceratopsidae',
#  'Libya',
#  'Whitney Joins The JAMs',
#  'Distilled beverage',
#  'Manifest Destiny',
#  'Ivory',
#  'Koryaksky',
#  'Photography',
#  'Phoenix Zoo',
#  'King Kong (1933 film)',
#  'Copenhagen',
#  'Winston Tunnel',
#  'Khartoum',
#  'Turner syndrome',
#  'Rail transport in India',
#  'Varanasi',
#  'Tripitaka',
#  'David Livingstone',
#  'Adenosine triphosphate',
#  'Sierra Leone',
#  'Barack Obama',
#  'Battle of Alesia',
#  'Caravaggio',
#  'Buckingham Palace',
#  'Libreville',
#  'Syria',
#  'Orca',
#  'Astatine',
#  'Logba language',
#  'Ruthenium',
#  'Population history of American indigenous peoples',
#  'Automatic number plate recognition',
#  'Scottish Gaelic language',
#  'Human dignity',
#  'Link (The Legend of Zelda)',
#  'Hero of Ukraine',
#  'Seattle, Washington',
#  'Weather map',
#  'Stanisław Lem',
#  'Animal law',
#  'Canadian House of Commons',
#  'Nahuatl language',
#  'Calvin and Hobbes',
#  'Rudyard Kipling',
#  'Race',
#  'Louis Jordan',
#  'Apaochi',
#  'Hampstead Heath',
#  'Hebrew calendar',
#  'Dwight D. Eisenhower',
#  'Antonio Vivaldi',
#  'Yangtze River',
#  'Black widow spider',
#  'Edinburgh',
#  'Cicely',
#  'Ununbium',
#  'Vulgar Latin',
#  'Linux',
#  'Donald Duck',
#  'Machu Picchu',
#  'Butter',
#  'Tacitean studies',
#  'Lake Tanganyika',
#  'United States Senate',
#  'Romeo and Juliet',
#  'Jackie Robinson',
#  'Economy of Africa',
#  'History of slavery',
#  'West Flemish',
#  'Blitzkrieg',
#  'Bee',
#  'Calgary',
#  'House Sparrow',
#  'Cultivar',
#  'Genetics',
#  'Cape Horn',
#  'Kigo',
#  'Wine',
#  'Australian Green Tree Frog',
#  'Zambezi',
#  'Antarctic krill',
#  'All Blacks',
#  'Taoism',
#  'Old Swiss Confederacy',
#  'Polonium',
#  'Global warming',
#  'GlaxoSmithKline',
#  'Jakarta',
#  'Abacus',
#  'Eurasian Eagle Owl',
#  'Red dwarf',
#  'Aztec',
#  'Mackenzie River',
#  'Theta',
#  'Telephone exchange',
#  'Pound sterling',
#  'Curium',
#  'Mary I of Scotland',
#  'Henry Morton Stanley',
#  'Heraclius',
#  'Norman conquest of England',
#  'Vitamin',
#  'Hyena',
#  'Pretoria',
#  'Cider',
#  'Blackbird',
#  'Nuclear power',
#  'Onion dome',
#  'International law',
#  'French Polynesia',
#  'Earth',
#  'Flemish (linguistics)',
#  'Vatican City',
#  'Sonic the Hedgehog (character)',
#  'North Sea',
#  'July 2006 Java earthquake',
#  'Strontium',
#  'Economy of Pakistan',
#  'Pachycephalosaurus',
#  'Jane Fonda',
#  'Corn oil',
#  'Achilles tendon',
#  'Galah',
#  'Bontebok',
#  'Solomon Islands',
#  'Sudanic languages',
#  'Directive Principles in India',
#  'Pop Idol',
#  'Iron Mike',
#  'Military dictatorship',
#  'Urial',
#  'Aral Sea',
#  'Howland Island',
#  'British Isles (terminology)',
#  'Benjamin of Tudela',
#  'Great white shark',
#  'Weather',
#  'Yes Minister',
#  'Sugarcane',
#  'Snowy Owl',
#  'Bangalore',
#  'Bjørnøya',
#  'Compsognathus',
#  'Propaganda',
#  'Asparagus',
#  'Virtuti Militari',
#  '16 Cygni',
#  'Karikkoselkä',
#  'French Revolution',
#  'Isaac Newton',
#  'Durham',
#  'Mount St. Helens',
#  'Jacques-Louis David',
#  'Rule of St Benedict',
#  'U.S. Navy Marine Mammal Program',
#  'Painting',
#  'Great Crested Grebe',
#  'Kuiper belt',
#  'Crime and Punishment',
#  'Tribe',
#  'Karachi',
#  'Nigeria',
#  'Indus Valley Civilization',
#  'Bath School disaster',
#  'Sport',
#  'Plover',
#  'Stanisław Koniecpolski',
#  'Crow',
#  'Chinese language',
#  'Pandanus',
#  'Episcopal polity',
#  'Mount Unzen',
#  'Timbuktu',
#  'Last Supper',
#  'Philosophy',
#  'Ludwig Wittgenstein',
#  'Plate tectonics',
#  'Comma Johanneum',
#  'Code of Hammurabi',
#  'Meat',
#  'Algorithm',
#  'Anaconda',
#  'Osiris',
#  'Utilitarianism',
#  'Italian Renaissance',
#  'Ateneo de Manila University',
#  'S-mine',
#  'Niccolò Paganini',
#  'Goldcrest',
#  'Sea of Galilee',
#  'John W. Johnston',
#  ...]

# %%
len(article_titles)
# Out:
# 4604

# %%
def construct_url_RationalWiki(title):
    if not isinstance(title, str):
        return None  # Return None or handle the error as appropriate

    normalized_title = title.lower().replace(' ', '_')  # Convert title to lowercase and replace spaces with underscores
    return f"https://rationalwiki.org/wiki/{normalized_title}"

def construct_url_Infogalactic(title):
    if not isinstance(title, str):
        return None  # Return None or handle the error as appropriate
    normalized_title = title.lower().replace(' ', '_')  # Convert title to lowercase and replace spaces with underscores
    return f"https://infogalactic.com/info/{normalized_title}"

def construct_url_Conservapedia(title):
    normalized_title = title.lower().replace(' ', '_')  # Convert title to lowercase and replace spaces with underscores
    return f"https://www.conservapedia.com/{normalized_title}"

# %%
#WARNING - This cell may take a long time to run (90min) - risk of blocked IP address because of too many requests
results = []

for title in article_titles:
    url = construct_url_RationalWiki(title)
    response = requests.get(url)

    # Store the title and the response status code
    results.append({'Article Title': title, 'Response Status': response.status_code})

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Optionally, save the DataFrame to a CSV file
df.to_csv('article_status_results_RationalWiki.csv', index=False)

print(df)
# Out:
#                     Article Title  Response Status
# 0                  Second Crusade              404
# 1                  Navassa Island              404
# 2                Evan Rachel Wood              404
# 3     Tropical Storm Henri (2003)              404
# 4         Final Fantasy Adventure              404
# ...                           ...              ...
# 4599                      Réunion              404
# 4600                       Flower              404
# 4601                     Banknote              404
# 4602               Weyto language              404
# 4603                    Marseille              404
#
# [4604 rows x 2 columns]

# %%
article_status_results_RationalWiki = pd.read_csv('./rationalWiki_article_status_results.csv')
article_status_results_RationalWiki['Response Status'].value_counts()
# Out:
# Response Status
# 404    3923
# 200     613
# 503      68
# Name: count, dtype: int64

# %%
def get_article_index(title):
    return article_titles.index(title)
print(get_article_index('Nepal'))
# Out:
# 19

# %%
#Test the html extract of rational wiki just for one article     

print(article_titles[19])
url = construct_url_RationalWiki(article_titles[19])
response = requests.get(url)
#print('Response status code: {0}\n'.format(response.status_code))
#print('Response headers: {0}\n'.format(response.headers))
#print('Response body: {0}'.format(response.text))
soup = BeautifulSoup(response.content, 'html.parser')

# Remove the specific navigation box
nav_box = soup.find('div', {'role': 'navigation', 'aria-labelledby': 'Nations_of_the_world-navigationbox'})
if nav_box:
    nav_box.decompose()

paragraphs = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    
text_content = ''
for para in paragraphs:
    for edit_link in para.find_all('span', class_="mw-editsection"): 
        edit_link.decompose()

    # Replace tags with spaces directly in the HTML
    html_with_spaces = re.sub(r'<[^>]+>', ' ', str(para))

    # Now create a new soup from the modified HTML
    new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

    # Extract text
    text = new_soup.get_text(strip=True, separator=' ')
    if text:
        text_content += text + '\n'
    
print(text_content)
# Out:
# Nepal
# Nepal
# The  Federal Democratic Republic of Nepal  is a country north of  India  best known for its Himalayas mountains. Nepal has at least partial control of eight of the world's ten tallest peaks, including Mt. Everest, Kanchenjunga, and Lhotse.  [2]   Most of Nepal's population is  Hindu , but there are significant minorities of  Buddhists  and  Muslims . Nepal's religious traditions go back a long way, and there are a variety of notable temples scattered across the country that attract tourism.  [3]   The country's capital and largest city is Kathmandu.
# Nepal's parliament has also been notoriously unstable. Nepal shuffles through governments at roughly one per year, as the legacies of war make political infighting both inevitable and unstoppable.  [41]   The peace commission, tasked with investigating  war crimes , murders, and  rapes  committed during the war, suffers from a lack of funding or direction.
# Gallery
# Kathmandu, Nepal's capital.
# Traditional Nepali rice meal.
# Tourists trekking through the Himalayas.
# Women at a Nepali wedding.
# Boudhanath, one of the world's largest Buddhist stupas.
# References
# Navigation menu
# Personal tools
# Namespaces
# Variants
# Views
# More
# Search
# Navigation
# Support
# Community
# Social media
# Tools

# %%
#Create the dataframe for rationalwiki with the layout usable with the NLP file.
df = pd.read_csv('./rationalWiki_article_status_results.csv')
df_rationalwiki_titles = df[df['Response Status'] == 200]
df_rationalwiki_titles = df_rationalwiki_titles.drop(columns=['Response Status'])
df_rationalwiki_titles = df_rationalwiki_titles.rename(columns={'Article Title': 'title'})
display(df_rationalwiki_titles)
# Out:
#                     title
# 19                  Nepal
# 22    Luminiferous aether
# 23                Chicago
# 25           Lyme disease
# 26                 Humour
# ...                   ...
# 4574              Bahrain
# 4578                Flood
# 4586              Neptune
# 4588             Hinduism
# 4591          Electricity
#
# [613 rows x 1 columns]

# %%
#Functions to extract the plain text of the website https://rationalwiki.org/ for every page that are present
# in both RationalWiki and Wikispedia dataset

def extract_text_rationalwiki(url):
    response = requests.get(url)
    if response.status_code != 200:
        return "Error: Unable to fetch article"

    soup = BeautifulSoup(response.content, 'html.parser')

    # Remove the specific navigation box
    nav_box = soup.find('div', {'role': 'navigation', 'aria-labelledby': 'Nations_of_the_world-navigationbox'})
    if nav_box:
        nav_box.decompose()

    paragraphs = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    
    text_content = ''
    for para in paragraphs:
        for edit_link in para.find_all('span', class_="mw-editsection"): 
            edit_link.decompose()

        # Replace tags with spaces directly in the HTML
        html_with_spaces = re.sub(r'<[^>]+>', ' ', str(para))

        # Now create a new soup from the modified HTML
        new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

        # Extract text
        text = new_soup.get_text(strip=True, separator=' ')
        if text:
            text_content += text + '\n'
    
    return text_content

    
# Main function to update DataFrame with text content
def update_df_with_text_content(df, csv_filename):
    texts = []
    for title in df['title']:
        url = construct_url_RationalWiki(title)
        if url is not None:
            text = extract_text_rationalwiki(url)
        else:
            text = "Invalid URL or title"  # Handle the case where URL is None
        texts.append(text)
        #time.sleep(1)  # Respectful crawl delay
    df['text_content'] = texts

    # Save the updated DataFrame to a CSV file
    df.to_csv(csv_filename, index=False)
    return df

# %%
#WARNING - This cell takes a long time to run
# Create the dataframe for rationalwiki with the plain text of articles.
df_rationalwiki_articles = update_df_with_text_content(df_rationalwiki_titles,'600_rationalwiki_common_articles.csv')

#if you want to use the DF delete the comment on the next line :
#df_rationalwiki_articles = pd.read_csv('./600_rationalwiki_common_articles.csv')

print(df_rationalwiki_articles)
# Out:
# /var/folders/2l/2h4s1yzx2gncjj51jv7w7m1c0000gn/T/ipykernel_96653/1981250232.py:27: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   new_soup = BeautifulSoup(html_with_spaces, 'html.parser')
#                    title                                       text_content
# 0                  Nepal  Nepal\nThe  Federal Democratic Republic of Nep...
# 1    Luminiferous aether  Luminiferous aether\nEther , or æther, was  th...
# 2                Chicago  Fun:Chicago\nChicago , of the oblast of  Illin...
# 3           Lyme disease  Lyme disease\nLyme disease   is an infectious ...
# 4                 Humour  Fun:Humeur\nHumeur  can refer to:\nHumeur, esp...
# ..                   ...                                                ...
# 608              Bahrain  Bahrain\nThe  Kingdom of Bahrain  is a tiny is...
# 609                Flood  Global flood\nThe global flood  is a (fairly s...
# 610              Neptune  Neptune\nNeptune  could use some help. Please ...
# 611             Hinduism  Hinduism\nHinduism  (not to be confused with  ...
# 612          Electricity  Fun:Electricity\nElectricity  is  a mystery fr...
#
# [608 rows x 2 columns]

# %%
#Get articles titles on Infogalactic that are in our Wikispedia Dataset 
 ##WARNING - This cell may take a long time to run (90min) - risk of blocked IP address because of too many requests
results = [] 

for title in article_titles:
    url = construct_url_Infogalactic(title)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers, timeout = 10)
    # Store the title and the response status code
    results.append({'Article Title': title, 'Response Status': response.status_code})

# Create a DataFrame from the results
df_infogalactic_titles = pd.DataFrame(results)

# Optionally, save the DataFrame to a CSV file
df_infogalactic_titles.to_csv('infogalactic_article_status_results.csv', index=False)

print(df_infogalactic_titles)

#How many corresponding titles beetween InfoGalactic and wikispedia
df_infogalactic_titles['Response Status'].value_counts()
# Out:
# "\nfor title in article_titles:\n    url = construct_url_Infogalactic(title)\n    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}\n    response = requests.get(url, headers=headers, timeout = 10)\n    # Store the title and the response status code\n    results.append({'Article Title': title, 'Response Status': response.status_code})\n\n# Create a DataFrame from the results\ndf_infogalactic_titles = pd.DataFrame(results)\n\n# Optionally, save the DataFrame to a CSV file\ndf_infogalactic_titles.to_csv('infogalactic_article_status_results.csv', index=False)\n\nprint(df_infogalactic_titles)\n\n#How many corresponding titles beetween InfoGalactic and wikispedia\ndf_infogalactic_titles['Response Status'].value_counts()\n"

# %%
#Create the dataframe for InfoGalactic with the layout for NLP file
df_infogalactic_titles = pd.read_csv('./infogalactic_article_status_results.csv')
df_infogalactic_titles = df_infogalactic_titles[df_infogalactic_titles['Response Status'] == 200]
df_infogalactic_titles = df_infogalactic_titles.drop(columns=['Response Status'])
df_infogalactic_titles = df_infogalactic_titles.rename(columns={'Article Title': 'title'})
display(df_infogalactic_titles)
# Out:
#                title
# 0     Second Crusade
# 5            Tornado
# 7     Whooping Crane
# 8             Shigin
# 9            Hafnium
# ...              ...
# 4599         Réunion
# 4600          Flower
# 4601        Banknote
# 4602  Weyto language
# 4603       Marseille
#
# [3664 rows x 1 columns]

# %%
#Test of html extract for infogalactic 
print(article_titles[19])
url = construct_url_Infogalactic(article_titles[19])
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers, timeout=10)

#print('Response status code: {0}\n'.format(response.status_code))
#print('Response headers: {0}\n'.format(response.headers))
#print('Response body: {0}'.format(response.text))

# Decode response content and apply regex
html_content = response.content.decode('utf-8')
cleaned_html = re.sub(r'<templatestyles.*?>.*?</templatestyles>', '', html_content, flags=re.DOTALL | re.IGNORECASE)


soup = BeautifulSoup(cleaned_html, 'html.parser')

# Find and remove all <templatestyles> tags
for template_style in soup.find_all('templatestyles'):
    template_style.extract()


# Process paragraphs and headings
paragraphs = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'])

text_output = ''
for para in paragraphs:
    for edit_link in para.find_all('span', class_="mw-editsection"): 
        edit_link.decompose()

    # Replace tags with spaces directly in the HTML
    html_with_spaces = re.sub(r'<[^>]+>', ' ', str(para))

    # Now create a new soup from the modified HTML
    new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

    # Extract text
    text = new_soup.get_text(strip=True, separator=' ')
    if text:
        text_output += text + '\n'

print(text_output)
# Out:
# Nepal
# Nepal
# <templatestyles src="Module:Hatnote/styles.css"></templatestyles>
# Nepal  (        i      /  n  ə  ˈ  p  ɔː  l  /   ;  [8]    Nepali :  नेपाल    [neˈpal]    (     listen ) ), officially the  Federal Democratic Republic of Nepal ,  [9]   is a  landlocked   country  located in  South Asia . With an area of 147,181 square kilometres (56,827 sq mi) and a population of approximately 27 million,  [2]   Nepal is the world's  93rd largest  country by area  [10]   and the  41st most populous  country. It is located in the  Himalayas  and bordered to the north by  China  and to the south, east, and west by  India . Nepal is separated from  Bangladesh  by the narrow Indian  Siliguri Corridor  and from  Bhutan  by the Indian state of  Sikkim .  Kathmandu  is the nation's  capital city  and largest metropolis.
# The mountainous north of Nepal has eight of the world's ten  tallest mountains , including the highest point on Earth,  Mount Everest  ( Nepali :  सगरमाथा   Sagarmāthā ). More than 250 peaks over 20,000 ft (6,096 m) above sea level are located in Nepal.  [11]   The southern  Terai  region is fertile and humid.
# Hinduism  is practiced by about 81.3% of Nepalis, the highest percentage of any country.  Buddhism  is linked historically with Nepal and is practiced by 9% of its people, followed by  Islam  at 4.4%,  Kiratism  3.1%,  Christianity  1.4%,  [2]   and  animism  0.4%.  [12]   A large portion of the population, especially in the hill region, may identify themselves as both Hindu and Buddhist, which can be attributed to the  syncretic  nature of both faiths in Nepal.  [13]
# A  monarchy  throughout most of its history, Nepal was ruled by the  Shah dynasty  of kings from 1768—when  Prithvi Narayan Shah  unified its many small kingdoms  [1]  —until 2008. A decade-long  Civil War  involving the  Communist Party of Nepal (Maoist) , followed by weeks of mass protests by all major political parties, led to the 12-point agreement  [14]   of 22 November 2005. The ensuing elections for the  1st Nepali Constituent Assembly  on 28 May 2008 overwhelmingly favored the abolition of the monarchy and the establishment of a  federal   multiparty   representative democratic   republic . Despite continuing political challenges, this framework remained in place, with the  2nd Nepali Constituent Assembly   elected in 2013  in an effort to create a  new constitution .
# On September 20, 2015, a new constitution  ( Nepali :  नेपालको संविधान २०७२ )  was announced by President  Ram Baran Yadav  in the Constituent Assembly. The Constituent Assembly was transformed into a legislative parliament. The new constitution established Nepal as a federal democratic country by making seven unnamed states.  [15]    [16]    [17]    [18]
# <templatestyles src="Module:Hatnote/styles.css"></templatestyles>
# Association football  is  the most popular sport in Nepal   [171]   and was first played during the  Rana dynasty  in 1921.  [172]   The one and only international stadium in the country is the  Dasarath Rangasala Stadium  where the  national team  plays its home matches.  [173]
# Cricket  has  been gaining popularity since the last decade . Since the establishment of the  national team , Nepal has played its home matches on the  Tribhuvan University International Cricket Ground .  [174]   The national team has since won the  2012 ICC World Cricket League Division Four  and the  2013 ICC World Cricket League Division Three   [175]   simultaneously hence qualifying for  2014 Cricket World Cup Qualifier . They also qualified for the  2014 ICC World Twenty20  in  Bangladesh .  [176]   On 28 June 2014, the  ICC  awarded  T20I  status to Nepal, who took part and performed exceptionally well in the  2014 ICC World Twenty20 .  [177]    [178]   Nepal had already played three  T20I  matches before gaining the status, as  ICC  had earlier announced that all matches at the  2014 ICC World Twenty20  would have  T20I  status.  [179]   Nepal won the  2014 ICC World Cricket League Division Three  held in  Malaysia  and qualified for the  2015 ICC World Cricket League Division Two .  [180]
# Nepal finished fourth in the  2015 ICC World Cricket League Division Two  in  Namibia   [181]   and qualified for the  2015–17 ICC World Cricket League Championship .  [182]   But Nepal failed to secure promotion to Division One and qualification to  2015–17 ICC Intercontinental Cup  after finishing third in the round-robin stage.  [183]    [184]    Basanta Regmi  became the first bowler to take 100 wickets in the  World Cricket League . He achieved this feat after taking 2 wickets against  Netherlands  in the tournament.  [185]
# Dasarath Rangasala Stadium
# Halchowk Studium
# See also
# References
# Further reading
# External links
# Lua error in package.lua at line 80: module 'strict' not found.
# Script error: The function "top" does not exist.
# Script error: The function "bottom" does not exist.
# Script error: The function "top" does not exist.
# Script error: The function "bottom" does not exist.
# Lua error in package.lua at line 80: module 'strict' not found.
# Navigation menu
# Personal tools
# Namespaces
# Variants
# Views
# More
# Search
# Navigation
# Tools
# /var/folders/2l/2h4s1yzx2gncjj51jv7w7m1c0000gn/T/ipykernel_1375/3878609852.py:35: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

# %%
# Remove duplicates from both DataFrames (df_infogalactic_titles, df_rationalwiki_articles)
df_infogalactic_titles = df_infogalactic_titles.drop_duplicates(subset='title')
df_rationalwiki_titles = df_rationalwiki_titles.drop_duplicates(subset='title')

# Perform the merge in order to have the articles titles that appears on rationalwiki, infogalactic and wikispeedia
common_titles_df = pd.merge(df_infogalactic_titles, df_rationalwiki_articles, on='title', how='inner')

#common_titles_df = common_titles_df.drop(columns=['text_content'])
# Display the DataFrames and the length of the merged DataFrame
display(common_titles_df)
print(len(common_titles_df.title.unique()))
# Out:
#                    title
# 0                  Nepal
# 1    Luminiferous aether
# 2                Chicago
# 3           Lyme disease
# 4                 Humour
# ..                   ...
# 608              Bahrain
# 609                Flood
# 610              Neptune
# 611             Hinduism
# 612          Electricity
#
# [613 rows x 1 columns]
# 608

# %%
#Functions to extract the plain text of the website infogalatic for every page that are present
# in both Infolgalactic and Wikispedia dataset

def extract_text_infogalactic(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

    response = requests.get(url, headers=headers, timeout=10)
    if response.status_code != 200:
        return "Error: Unable to fetch article"
    
    html_content = response.content.decode('utf-8')
    cleaned_html = re.sub(r'<templatestyles.*?>.*?</templatestyles>', '', html_content, flags=re.DOTALL | re.IGNORECASE)

    soup = BeautifulSoup(cleaned_html, 'html.parser')

    # Find and remove all <templatestyles> tags
    for template_style in soup.find_all('templatestyles'):
        template_style.extract()
    

    paragraphs = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    
    text_content = ''
    for para in paragraphs:
        for edit_link in para.find_all('span', class_="mw-editsection"): 
            edit_link.decompose()

        # Replace tags with spaces directly in the HTML
        html_with_spaces = re.sub(r'<[^>]+>', ' ', str(para))

        # Now create a new soup from the modified HTML
        new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

        # Extract text
        text = new_soup.get_text(strip=True, separator=' ')
        if text:
            text_content += text + '\n'
    
    return text_content

    
# Main function to update DataFrame with text content
def update_df_with_text_content_Infogalactic(df, csv_filename):
    texts = []
    for title in df['title']:
        url = construct_url_Infogalactic(title)
        if url is not None:
            text = extract_text_infogalactic(url)
        else:
            text = "Invalid URL or title"  # Handle the case where URL is None
        texts.append(text)
        #time.sleep(1)  # Respectful crawl delay
    df['text_content'] = texts

    # Save the updated DataFrame to a CSV file
    df.to_csv(csv_filename, index=False)
    return df

# %%
##WARNING this cell might take a long time to run
#Scrap the articles on infogalactic that are both present in wikispeedia and rationalwiki
df_infogalactic_articles = update_df_with_text_content_Infogalactic(common_titles_df, '600_infogalactic_common_articles.csv')

#if you want to use the DF delete the comment on the next line :
#df_infogalactic_articles = pd.read_csv('scraped_data/infogalactic_articles.csv')

display(df_infogalactic_articles)
# Out:
# /var/folders/2l/2h4s1yzx2gncjj51jv7w7m1c0000gn/T/ipykernel_1375/1765758027.py:32: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   new_soup = BeautifulSoup(html_with_spaces, 'html.parser')
#                    title                                       text_content
# 0                  Nepal  Nepal\n<templatestyles src="Module:Hatnote/sty...
# 1    Luminiferous aether  Luminiferous aether\nIn the late 19th century,...
# 2                Chicago  Chicago\n<templatestyles src="Module:Hatnote/s...
# 3           Lyme disease  Lyme disease\nLyme disease , also known as  Ly...
# 4                 Humour  Humour\n<templatestyles src="Module:Hatnote/st...
# ..                   ...                                                ...
# 608              Bahrain  Bahrain\n<templatestyles src="Module:Hatnote/s...
# 609                Flood  Flood\n<templatestyles src="Module:Hatnote/sty...
# 610              Neptune  Neptune\n<templatestyles src="Module:Hatnote/s...
# 611             Hinduism  Hinduism\nLua error in package.lua at line 80:...
# 612          Electricity  Electricity\n<templatestyles src="Module:Hatno...
#
# [613 rows x 2 columns]

# %%
# Function to get a random RationalWiki article title
def get_random_rationalwiki_title():
    response = requests.get('https://rationalwiki.org/wiki/Special:Random')
    soup = BeautifulSoup(response.content, 'html.parser')
    
    if soup.title and soup.title.string:
        return soup.title.string.split(' - RationalWiki')[0]
    else:
        return None

# Function to check if a title exists on InfoGalactic
def check_infogalactic(title):
    url = construct_url_Infogalactic(title)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        # Check if response is successful and title is in the response text
        is_successful = response.status_code == 200 and title in response.text
        return is_successful, is_successful
    except requests.exceptions.RequestException as e:
        return False, str(e)

# %%
#WARNING - This cell takes a long time to run - It finds 3000 articles that are in both RationalWiki and InfoGalactic but not in wikispeedia 
#this will allow us to train our model.

# Initialize an empty DataFrame
training_articles2 = pd.read_csv('training_articles_titles.csv')

# Loop until collection of 3000 unique articles
while len(training_articles2) < 3000:
    random_title = get_random_rationalwiki_title()

    # Check conditions
    success, message = check_infogalactic(random_title)
    if random_title not in article_titles and random_title not in training_articles2['Title'].values and success:
        # Add to DataFrame if conditions are met
        training_articles2.loc[len(training_articles2)] = [random_title]

    # Save to CSV file after every 100 additions
    if len(training_articles2) % 100 == 0:
        training_articles2.to_csv('training_articles_titles.csv', index=False)

print("Collection complete. Final list saved to 'training_articles_titles.csv'.")
# Out:
# '\n# Initialize an empty DataFrame\ntraining_articles2 = pd.read_csv(\'training_articles2.csv\')\n\n# Loop until collection of 3000 unique articles\nwhile len(training_articles2) < 3000:\n    random_title = get_random_rationalwiki_title()\n\n    # Check conditions\n    success, message = check_infogalactic(random_title)\n    if random_title not in article_titles and random_title not in training_articles2[\'Title\'].values and success:\n        # Add to DataFrame if conditions are met\n        training_articles2.loc[len(training_articles2)] = [random_title]\n\n    # Save to CSV file after every 100 additions\n    if len(training_articles2) % 100 == 0:\n        training_articles2.to_csv(\'training_articles2.csv\', index=False)\n\nprint("Collection complete. Final list saved to \'training_articles2.csv\'.")'

# %%
training_articles = pd.read_csv('./training_articles_titles.csv')
training_articles
# Out:
#                            Title
# 0      Electroconvulsive therapy
# 1                          Juche
# 2               Special pleading
# 3                       Chrislam
# 4                      Black box
# ...                          ...
# 2995           Four-term fallacy
# 2996                      Nosode
# 2997        Very special episode
# 2998  The Man in the High Castle
# 2999                     MKULTRA
#
# [3000 rows x 1 columns]

# %%
#WARNING - Cell take a long time to run - It will extract the plain text of the 3000 articles that are in both RationalWiki and InfoGalactic but not in wikispeedia
training_articles = training_articles.rename(columns={'Title': 'title'})
df_infogalactic_training_articles = update_df_with_text_content_Infogalactic(training_articles, '3000_infogalactic_training_articles.csv')
df_rationalwiki_training_articles = update_df_with_text_content(training_articles, '3000_rationalwiki_training_articles.csv')
# Out:
# /var/folders/2l/2h4s1yzx2gncjj51jv7w7m1c0000gn/T/ipykernel_1375/1765758027.py:32: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   new_soup = BeautifulSoup(html_with_spaces, 'html.parser')
# /var/folders/2l/2h4s1yzx2gncjj51jv7w7m1c0000gn/T/ipykernel_1375/1872830119.py:27: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   new_soup = BeautifulSoup(html_with_spaces, 'html.parser')

# %%
df_rationalwiki_training_articles = pd.read_csv('./3000_rationalwiki_training_articles.csv')
df_infogalactic_training_articles = pd.read_csv('./3000_infogalactic_training_articles.csv')
error_count1 = df_rationalwiki_training_articles['text_content'].value_counts().get('Error: Unable to fetch article', 0)
error_count2 = df_infogalactic_training_articles['text_content'].value_counts().get('Error: Unable to fetch article', 0)

print(f"Error count for RationalWiki: {error_count1}") 
print(f"Error count for InfoGalactic: {error_count2}")
# Out:
# Error count for RationalWiki: 782
# Error count for InfoGalactic: 0

# %%
df_rationalwiki_training_articles = df_rationalwiki_training_articles[df_rationalwiki_training_articles['text_content'] != 'Error: Unable to fetch article']
error_count1 = df_rationalwiki_training_articles['text_content'].value_counts().get('Error: Unable to fetch article', 0)
error_count2 = df_infogalactic_training_articles['text_content'].value_counts().get('Error: Unable to fetch article', 0)

df_rationalwiki_training_articles.to_csv('./3000_rationalwiki_training_articles.csv')

print(f"Error count for RationalWiki: {error_count1}")
print(f"Error count for InfoGalactic: {error_count2}")
# Out:
# Error count for RationalWiki: 0
# Error count for InfoGalactic: 0

# %%
import csv
import sys

# Increase the maximum field size limit
csv.field_size_limit(sys.maxsize)

# Text patterns to remove
patterns_to_remove = [
    '<templatestyles src="Module:Hatnote/styles.css"></templatestyles>',
    '<templatestyles src="Template:Blockquote/styles.css"/>',
    '<templatestyles src=""Template:Blockquote/styles.css""/>',
    ' <templatestyles src=""Template:Blockquote/styles.css"" /> ', 
    '<templatestyles src="Div col/styles.css"/>',
    '<templatestyles src="Template:TOC limit/styles.css"/>',
    '<templatestyles src=""Template:TOC limit/styles.css"" />',
    '<templatestyles src=""Template:TOC limit/styles.css"" />', 
    '<templatestyles src=""Template:TOC limit/styles.css"" />', 
    '<templatestyles src=""Template:Blockquote/styles.css"" />', 
    '<templatestyles src=""Template:TOC limit/styles.css"" />',
    '<templatestyles src=""Noitalic/styles.css""/>',
    '"<templatestyles src=""""Template:Quote_box/styles.css"""" />"', 
    '"<templatestyles src=""""Template:Quote_box/styles.css"""" />"',
    '<templatestyles src=""""Sfrac/styles.css"""" />',
    '<templatestyles src=""""Sfrac/styles.css"""" />',
    'templatestyles src=""""Sfrac/styles.css""""', 
    '<templatestyles src=""""Script/styles_hebrew.css"""" />'

   # Unescaped double quotes
]


input_file_path = './11_clean_600_infogalactic_common_articles.csv'  # Replace with your CSV file path
output_file_path = './12_clean_600_infogalactic_common_articles.csv'  # Replace with your desired output file path

with open(input_file_path, mode='r', encoding='utf-8') as infile, \
     open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    for row in reader:
        modified_row = row
        for pattern in patterns_to_remove:
            # Replace each pattern with a line break in each row
            modified_row = [cell.replace(pattern, '\n') for cell in modified_row]
        writer.writerow(modified_row)

print("CSV file has been processed and saved.")
# Out:
# CSV file has been processed and saved.

# %%
import csv
import sys
import re

csv.field_size_limit(sys.maxsize)

# Regular expression pattern for matching the block of text
pattern_to_remove = re.compile(r'See also.*?Tools', re.DOTALL)

input_file_path = './12_clean_600_infogalactic_common_articles.csv'
output_file_path = './13_clean_600_infogalactic_common_articles.csv'

with open(input_file_path, mode='r', encoding='utf-8') as infile, \
     open(output_file_path, mode='w', encoding='utf-8', newline='') as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    for row in reader:
        modified_row = [re.sub(pattern_to_remove, '', cell) for cell in row]
        writer.writerow(modified_row)

print("CSV file has been processed and saved.")
# Out:
# CSV file has been processed and saved.
